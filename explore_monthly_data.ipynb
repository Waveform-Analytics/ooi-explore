# %% [markdown]
# # Explore monthly datasets

# %%
import xarray as xr

# %%
# Load an example netcdf file
file_name = "data/RS03AXBS-LJ03A-09-HYDBBA302-YMD.2024.01.01.nc"
ds = xr.open_dataarray(file_name)
ds
# Out:
# <xarray.DataArray (time: 288, frequency: 101)> Size: 233kB
# [29088 values with dtype=float64]
# Coordinates:
#   * frequency  (frequency) float64 808B 0.0 2.0 4.0 6.0 ... 196.0 198.0 200.0
#     quantile   float64 8B ...
#   * time       (time) datetime64[ns] 2kB 2024-01-01 ... 2024-01-01T23:55:00

# %%
sample = ds.isel(time=120)

# %%
ds = xr.open_dataarray('data.nc')
sample = ds.isel(time=120)
# Out:
# <xarray.DataArray (frequency: 101)> Size: 808B
# [101 values with dtype=float64]
# Coordinates:
#   * frequency  (frequency) float64 808B 0.0 2.0 4.0 6.0 ... 196.0 198.0 200.0
#     quantile   float64 8B ...
#     time       datetime64[ns] 8B 2024-01-01T10:00:00

# %%
# Extract data
frequency_data = ds['frequency']
time_data = ds['time']
quantile_data = ds['quantile']
array_data = ds['__xarray_dataarray_variable__']
# Out:
# xarray.core.dataarray.DataArray
